# %% [markdown]
# Course: CPSC 346 Operating Systems
#
# Office hours: Mon 2:10 - 4:10, W 2:45 - 4:45
# Email: zhangy@gonzaga.edu
#
# ** Check projects in ADA before submitting **
#
# Modules:
#     OS: kernal mode
#         * privileged mode ( trusted )
#         * access to all of hardware
#     All other software: User mode
#         * when needs to deal with hardware, OS is used
#         * Not trusted
#
# Tasks of OS:
#     * shield user of complexity
#     * allocate resources to competing users
#     * allocates cpu, printer, memory
#
# 5 Primary Tasks
#     * Process management
#     * Memory management
#     * Storage management
#     * I/O subsystem
#     * security and protection
#
# - Order of software
#     * HLL => compiler = assembly code => Assembler = binary (machine code) => Linker (copies piece from library)
#     => executable machine code => Loader = executable in memory => Computer architecture
#
# ----C Background----
#
# - Local variables are uninitialized
# c = 'l';
# d = 2;
# printf("%d\t%c\n",i,c);
#
# scanf = cin<<
# scanf("%d", &x);
#
# int main(){
#     int j = 8;
#     int a[100]
#     int i;
#     for(i=0;i<=100;i++) a[i] = i;
#     printf("%d\n",j);
# }
# output:
#     100
#
# Structures
#     * struct ComplexNumber{
#         float real;
#         float imag;
#     };
#     struct ComplexNumber x;
#     x.real = 3.1;
#
# malloc: like new in C++
#     - struct node* new_node = (struct node*)malloc(sizeof(struct node));
#     - if(new_node!=NULL) continue...
# free: like delete in C++
#     - free(new_node);
#     - new_node = NULL;
#
# typedef struct ComplexNumber{
#     float real;
#     float imag;
# } complex;
# complex a,b*;
#
# int *p;
# int a = 4;
# p = &a;
# prints address
#
# swap(int *i, int *j){
#     int *temp
#     temp = i; i=j;j=temp;
# }
# main(){
#     int a = 4;
#     int b = 8;
#     swap(&a,&b);
# }
# - only modifies adress of local variables
#
# dereference with *i and *j
#
# X86 architecture:
#
# - Process (used to run programs): Code Secion, data section, heap, stack
#     * Stack stores local variables and maintains a frame
#     * Frame pointer register maintains Structure
#
# 64-bits
# * Stack operations
#     - push and pop, what do they modify
#         * % rsp, % rbp
#
# 16 - general purpose registers
#     - can be modified by programmer, cannot modify things like construction pointer
#
# 32-bits
# 8 general purpose registers
#
# 64-bit machines have 64 bit registers and capacity for memory
#
# - use stack to preserve the old ebp value
#     - Frame pointer from the caller
#
# %rip is always pointing towards the next instruction to be executed
# Code section is read only
# %esp always holds a memory address (32 bits)
#     * Everytime you push something, it removes 4 bytes
#     * Pop, adds 4 bytes to the esp address
#         - add/remove 8 for 64 bit
#         pop = add 8, push = -8
# When calling a function, the function call is already fetched in the CPU, with the
# Instruction pointer still on the next line of code in main
# % rax is return value register
#
# Kernel Mode: Exceptions/errors, interrupts like selecting something with mouse
#
# Primative case:
#
# Label is just a different name of a memory address
#
# 1. callq: Fetched by CPU but not executed yet
#     %rsp = 0x120
#     %rip = 400549
#
# 2. right after callq is executed:
#     % rsp = 400557
#     % rip = 400550
#
# Processes:
# - Containers for programs
#     Virtual memory
#         address space
#     scheduling
#         one or more threads of control
#     file references
#         open files
# Which instructions should be privileged?
#     * i/o instructions
#     * Only the kernel is privileged
#
# OS is invoked soley for interrupts and Exceptions
#     * i/o devices demand attention
#     * timers expire
#     * programs need os services and Storage

# %% [markdown]
# ```c
# typedef struct ComplexNumber{
#     float real;
#     float imag;
# } complex;
# complex a,b*;
#
# int *p;
# int a = 4;
# p = &a;
# prints address
#
# swap(int *i, int *j){
#     int *temp;
#     temp = i;
#     i=j;
#     j=temp;
# }
# main(){
#     int a = 4;
#     int b = 8;
#     swap(&a,&b);
# }
#
# swap(int *i, int *j){
#     int temp
#     temp = *i; *i=*j;*j=temp;
# }
# main(){
#     int a = 4;
#     int b = 8;
#     swap(&a,&b);
# }
#
# fork();
#     // Telling the operating system to create a new Process
#     if((pid = fork()) == 0){
#         new Process
#     }
#
# pid_t pid;
# pid_t ParentPid = getpid()
# if((pid = fork()) == 0)
#     printf("Child: %d, %d, %d\n", pid,ParentPid,getpid());
#     return 0;
# printf("Parent: %d, %d, %d,\n", pid, ParentPid,getpid());
# ```

# %% [markdown]
# fork() called once and returns twice
#     - parent returns memory address of child and child returns 0
# *
# Exceptions:
# * Event arrives, exception is thrown and then it is transfered to kernel mode
# * Processed by exception handler
# * Returns to current instruction, goes to next instruction or aborts program
# 1. Page exception
# 1. Invalid memory reference
#
#
# ##### System Calls:
# Ex.
# They have specific numbers
# |Number|Name|Description|
# |-----|------|------
# |0|read|Readfile|
# |1|write|Write file|
# |2|open| Open File|
# |57|fork|Create Process|
#
# Negative return value is an errno, used to track number of errors
#
# ```c
# int value = 5;
# pid_t pid;
#
# if((pid = fork()) ==0){
#     value += 15;
#     printf("Child value: %d\n",value) // prints 20
# }
# else if (pid > 0){
#     printf("Parent: value %d",value) // prints 5
# }
#
#
# if(fork()==0){
#     printf("p1: x=%d",++x); // Child prints 2 here
# }
# printf("p2: x=%d",--x); // child prints 1 and 0 here; for child and parent respectively
#
# /*
# prints:
# p1: x = 2
# p2: x = 1
# p2: x = 0
# */
#
# int value = 5;
# pid_t pid;
#
# if((pid = fork()) ==0){
#     value += 15;
#     printf("Child value: %d\n",value) // prints 20
#     return 0;
# }
# else if (pid > 0){
#     wait(NULL); // waits for child process to be NULL
#     printf("Parent: value %d",value) // prints 5
#     return 0;
# }
#
# ```

# %% [markdown]
# ## Exam 1: Oct 5th

# %% [markdown]
# ### Program 2 Notes
# * Program should be able to handle errors, returns -1
# * char* argv[] = {"./MyProg","12",(void*)0};
# * execv("./random",argv); starts another process
# * waitpid(pid,&status,0); # the & means the process runs in the background
#     * waits for child to complete
# * External command 'kill' can be used to end a process
#
# - Zombie process (most often child) = half alive half dead, completed but still in memory
# - Reaping
# * performed by parent on terminated child ( using wait or waitpid )
# * kernel deletes zombie child process
# * if a parent terminates without reaping, an orphaned child will be reaped by init pid ==1
#     * pstree will show parent/child heirarchy

# %% [markdown]
# Signal:
# * Kernel will send a program a signal to let them know when background processes are finished
#
# Fork, one call 2 return
# exit, one call no return
# repeaing adn waiting for processes
# call wait or waitpid
# loading and running programs
# call execve (or variant)
# one call, normally no return

# %% [markdown]
# ##### Process states:
# * new: Process being created
# * running: instructions being executed
# * waiting: the process is waiting for an event to occur
# * ready: wayiting to be assigned to a processir
# * Terminated: The process has finished execution
#
# Note: Short-term scheduler: selects from among the processes in queue and allocates the CPU to one of them
#
# ##### CPU scheduling decisions:
# 1. switches from running to waiting state, ex. I/O request or invocation of the wait()
# 1. Switches from running to ready
# 1. switches from waiting to ready
# 1. terminates
#     * scheduling for 1 and 4 is nonpreemptive and cooperative
#     * Once a process starts running, keeps running until blocked or finished
#     * All other scheduling is preemptive
#
# ##### Scheduling Criteria:
# * Throughput: # of processes that complete per unit of time
# * Turnaround Time: Amount of time to execute a process
# * waiting time: Amount of time a process is waiting in queue
# * Response Time: amount of time to get the first response
#
# ### NOTES:
# * FIFO, SJO, SRT, Priority, Round Robin, priority
# Response time:
# * CPU - Arrival time = RT
# Waiting time:
# * RT + (time in ready queue while unfinished) = WT
# Turnaround time:
# * Time finished - Arrival time = TT

# %% [markdown]
# Gantt Chart: type of bar chart that illustrates a project schedule
#
# |C.P.U Burst| P1|P2|P3||
# |----------|----|---|---|-|
# |I/O|0|5|8|15|
#
# Processing status:
#
# ||R.T|W.T|T.T|
# |--|--|--|--|
# |P1|0|0|5|
# |P2|5|5|8|
# |P3|8|8|15|

# %% [markdown]
# <h5>Ex.</h5>
#
# Process:
# * p1  24
# * p2  3
# * p3  3
#
# |C.P.U Burst| P1|P2|P3|
# |----------|---------|-|-|
# |I/O|24|27|30|
#
# waiting time: P1 = 0; p2 = 24; p3 = 27
#
# new ex.
#
# |Process|C.P.U|I/O|C.P.U|Arrival|=>||R.S|W.T|T.T|
# |--|--|--|--|--|-|-|-|-|-|
# |P1|5|6|7|0||11|0|(0-0)+(16-11)=5|23|
# |P2|4|3|3|3||12|5-3=2|(5-3)+(23-12)=13|26-3=23|
# |P3|2|3|4|4||14|9-4=5|(9-4)+(26-14)=17|30-4=26|
# |P4|5|2|7|7||18|11-7=4|(11-7)+(33-18)=19|40-7=33|
# |P5|3|2|4|15||35|30-15=15|(30-15)+(40-35)=20|44-15|
#
# Produces this Gantt chart:
# ||P1|P2|P3|P4|P1|P2|P3|P5|P4|P5|End|
# |-|-------|-|-|-|-|-|-|-|-|-|-|
# |I/O|0|5|9|11|16|23|26|30|33|40|44|

# %% [markdown]
# ##### Round Robin
# * preemptive FIFO
# * Time quantum q
#     * When large q -> FIFO
#     * small q -> q should be larger than context switching
# * high avg. turnaround, but better response

# %% [markdown]
# #### Round Robin Examples:
# ##### $T_q = 4$
#
# |Process|CPU|
# |-|-|
# |P1|24|
# |P2|3|
# |P3|3|
#
# Produces:
#
# |p1|p2|p3|p1|p1|p1|p1|p1|
# |-|-|-|-|-|-|-|-|
# |0->4|4->7|7->10|10->14|14->18|18->22|22->26|26->30|

# %% [markdown]
# ##### $T_q = 5$
#
# |Process|Arrival|CPU|R.T|W.T|T.T|
# |-|-|-|-|-|-|
# |P1|0|8->3->0|0|0+(13-5)=8|16|
# |P2|3|3->0|5-3=2|2|8-3=5|
# |P3|4|10->5|8-4=4|4+(26-13)=7|31-4=27|
# |P4|6|9->4|16-6=10|10+(31-21)=20|35-6=29|
# |P5|11|7->2|21-11=10|10+(35-26)=19|37-11=26|
#
# ##### Gantt chart:
#
# |p1|p2|p3|p1|p4|p5|p3|p4|p5
# |-|-|-|-|-|-|-|-|-|
# |0->5|5->8|8->13|13->16|16->21|21->26|26->31|31->35|35->37|

# %% [markdown]
# ##### Multilevel Queue
# * Partioned into separate queues
#     * foreground
#         * uses Round Robin
#     * background
#         * uses FCFS
# * Scheduling must be done between queues
#     * Fixed priority scheduling, serve all from foreground before background
# * Time slicing = each queue gets a certain portion of CPU time and can use it to schedule its own processes

# %% [markdown]
# ##### $T_q1 = 4$
# ##### $T_q2 = 3$
#
# |Process|Arrival|CPU|Q|R.T|W.T|T.T|
# |-|-|-|-|-|-|-|
# |P1|0->3->12|10->7->5|2|0|24|34|
# |P2|3->7|7->3->0|1|0|0|7|
# |P3|4->18|6->5|2|13|26|32|
# |P4|12|5->1->0|1|0|0|5|
# |P5|18|8|1|0|0|8|
#
# <br>
#
# |p1|p2|p2|p1|p4|p4|p3|p5|p5|p1|p3|p1|p3|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |0->3|3->7|7->10|10->12|12->16|16->17|17->18|18->22|22->26|26->29|29->32|32->34|34->36|

# %% [markdown]
# * Multilevel-feedback-queues"
#   * number of queues
#   * scheduling algorithms for each queue
#   * method used to upgrade/demote a process
#   * determining which queue a process will enter
# * Three queues:
#   * Q0 - RR with 8 ms
#   * Q1 RR with 16 ms
#   * FCFS

# %% [markdown]
# - I/0 =
# - 2nd CPU
# * $Q1: T_q = 4$
# * $Q2: T_q = 7$
# * $Q3: T_q = FCFS$
# Note: WTF
#
# | Process | CPU   | I/O | CPU        | Arrival    | Queue | W.T | T.T |
# | ------- | ----- | --- | ---------- | ---------- | ----- | --- | --- |
# | p1      | 5-1-0 | 6   | 7          | 0-4-31-44  | 1-2   |     |     |
# | p2      | 4-0   | 3   | 3          | 3-11-17    | 1     |     |     |
# | p3      | 2-0   | 3   | 4          | 4-13-21    | 1     |     |     |
# | p4      | 5-1-0 | 2   | 7-21(19+2) | 7-14-28-37 | 1-2   |     |     |
# | p5      | 3-0   | 2   | 4          | 15-26-30   | 1     |     |     |
#
# <br>
# Gantt Chart:
#
# | p1  | p2  | p3   | p4    | p2    | p3    | p5    | p1    | p4    | p5    | p4    | p1    |
# | --- | --- | ---- | ----- | ----- | ----- | ----- | ----- | ----- | ----- | ----- | ----- |
# | 0-4 | 4-8 | 8-10 | 10-14 | 14-17 | 17-21 | 21-24 | 24-25 | 25-26 | 26-30 | 30-37 | 37-44 |

# %% [markdown]
# * Lottery: 0~99
#   * A: 0~24 ( 25% )
#   * B: 25~99 ( 75% )
# * Number 1-100 generated, depending on number certain process gets CPU
#
# #### Threads:
# * Abstraction of a processor
# * A thread of control
# - Why threads?
# * concurrency: multiprocessor and equally useful on uniprocessors
#
# #### Processes vs. Threads:
# * Both provide concurrency
#   * Much cheaper to add a thread than create a new process
#   *

# %% [markdown]
# #### Multi-threads cont.
# - phread_create([],0,task,arg)
# - void* task(void*)
# - pthread_join
# - pthread_exit() = waits for all other peers to complete

# %% [markdown]
# #### Project 4:
# * List = [] Note: Not allowed to make another list
#
#   * 2: sorter threads
#   * 1 merger thread

# %% [markdown]
# #### Thread:
# * Thread ID
# * Stack
# * Stack pointer($rsp)
# * Program counter ($Rip)
# * FLAG(condition codes)
# * General Purpose Register (%rax)
# ________________________________
# * Sharing:
#     - Virtual address space
#     - Code
#     - Data
#     - Heap * open files
# - pthread_join()
#   - some information is maintained for each thread, for switching purposes
#   - waits for other threads
#
# - Mutexes:
#   - provides mutual exclusion, one thing can access it at a time
#   - protects `critical section`
#     - Without this, could cause unpredictable values every runtime
# ```c
# pthread_mutex_t m = PTHREAD_MUTEX_INITIALIZER;
# pthread_mutex_lock(&m);
# pthread_mutex_unlock(&m);
# ```

# %% [markdown]
# ## Exam 2: Nov. 11
# <br>
#
# # Multi-thread Concurrency
# There are several different OS problems that we often talk about
# Note: value for var empty and occupied must be at least 1
# -
# 1. Dining Philosophers:
#     * 5 Philosophers, 5 Chopsticks
#     * In the middle is a plate of spaghetti
#     * They can either
#       * think (like a philosopher does)
#       * eat
#       * sleep
#     * If they eat, they need to pick up two chopsticks
#     * you dont want them to starve
#     * so its all about managing the timing for eating and sleeping (and thinking)
# 2. Producer - Consumer
#    * a producer makes stuff, while a consumer consumes it.
#    * For the producer to add onto the array
#      * must be EMPTY
#      * since we dont want them to overwrite any data
#      * So there is a guard
#    * For the consumer to take away something on the array
#      * must be OCCUPIED
#      * since we dont want them to overflow the array
# 1. Reader-Writer. Prob
#     - Semaphore: integer >=0
#         * (Binary, accumulate)
#     * P(S): S -= 1; (semaphore)
#     * make sure is positive or 0
# - V(s): S +=1;
# - P(s): S -=1;

# %% [markdown]
# #### Reader - Writer: Same data structure
# * Only one writer is allowed to be active ( no other writers, no other readers)
# * Multiple readers are allowed to be actice (no writers)

# %% [markdown]
# ### Memory Hierarchy:
# * Comprised of CPU (~1000 bit)
#   - 20 picoseconds
# * Cache
#   - SRAM (~10 ns)
# * Main Memory (GB DRAM)
#   - ~50ms
# * "Virtual Memory"
#     - "Page" (fixed block of virtual memory)
# * Hard Disk (TB)
#   - 10ms
#
# <br>
#
# * Locality:
#   1. Temporal locality
#      * Recently accessed data
#      * Ex. Variables in loops will most likely need to be accessed again (index)
#   2. Spatial locality
#      * Ex. Arrays, nearby data and instructions
#
# ### EX:
# ```c
# sum = 0;
# for(int i = 0; i < array.size; i++){
#     sum += a[i];
# }
# ```
# * Accessing sum is temporal locality
# * Accessing a[] is spatial locality

# %% [markdown]
# ## Cache:
# * num blocks * block size = size of cache
# * Hit ratio = hit/successes
# * Miss ratio = 1-hit ratio
# * Avg access time: Hit time + Miss ratio * Miss penalty
# * Miss penalty = time wasted after miss in cache
#
# ### Direct Mapped Cache
# * Block address in memory % blocks in cache (to determine location)
#   * mem addr.   cache index.
#   * 10101 % 8 = 101 (5)
#   * 11001 % 8 = 001 (1)
# * Only one memory location for each block in cache
# * We need to store the high order bits in order to distinguish the blocks in memory ( Tags ) mapping 101 -> 10101
#   * Valid bit: 1 = present, 0 = not present (initial value)
#   * If is a miss, copy memory block into the index
# * Inserting:
# WordAddress Valid Tag Data
# <br>

# %% [markdown]
# <h2 style="color:#61dbfb ;" >Exam Topics: </h2>
#
# * CPU Scheduling (RR, multi-level queue, multi-level feedback queue)
# * Thread vs. Process:
#   * share data, code, heap
#   * Has its own stack
#   * create and terminate threads
# * Mutex: Deadlock
#   * define an order: lock m1 then m2
#   * try_lock: try to lock one and then lock another
#   * WRITE LIBRARY FUNCTIONS maybe the loop as well
# * Semaphore
#   * dining philosophers
#   * producer/consumer
#   * reader/writer

# %% [markdown]
# |Tag(bits)|Index(bits)|Byte_Offset(bits) |
# |---|-----|------------|
# | 22(10->31) |  6(4->9)  |    4(0->3)    |

# %% [markdown]
# ### Associative Cache
# * $n = \frac{ number\ cache\ blocks}  {number\ sets} $
#
# #### Fully associative:
# * Allow a given block to go into any cache entry
# * All entries must be searched at once
#
# #### n-way associative
# * Each set contains n entries
# * block address determines the set
#   * $\frac{ number\ cache\ blocks}  {number\ sets}$
#
# CCAA = Cache_content_after_access
# #### Direct-Mapped example:
#
# | Block Address | Cache index | Hit/miss | CCAA0                | CCAA1 | CCAA2 | CCAA3 |
# | ------------- | ----------- | -------- | -------------------- | ----- | ----- | ----- |
# | 0             | 0           | miss     | Mem[0]               |       |       |       |
# | 8             | 0           | miss     | Mem[8] (Replacement) |       |       |       |
# | 0             | 0           | miss     | Mem[0] (Replacement) |       |       |       |
# | 6             | 2           | miss     | Mem [0]               |       |  mem[6]     | |
# | 8             | 0           | miss     | Mem[8] (Replacement) |       |   mem[6]   | |
#
# #### 2-way set associative example:
# | Block Address | Cache index | Hit/miss | CCAA0                | CCAA1 | CCAA2 | CCAA3 |
# | ------------- | ----------- | -------- | -------------------- | ----- | ----- | ----- |
# | 0             | 0           | miss     | Mem[0]               |       |       |       |
# | 8             | 0           | miss     | Mem[0] (Replacement) | Mem[8]      | Mem[8]      ||
# | 0             | 0           | hit     | Mem[0] (Replacement) |  Mem[8]     | Mem[8]      | |
# | 6             | 0           | miss     | Mem [0]               | Mem[6]      | Mem[6]    | |
# | 8             | 0           | miss     | Mem[8] (Replacement) |  Mem[6]     |  Mem[6]  | |
#
# #### Fully Associative
# | Block Address | Cache index | Hit/miss | CCAA0                | CCAA1 | CCAA2 | CCAA3 |
# | ------------- | ----------- | -------- | -------------------- | ----- | ----- | ----- |
# | 0             | 0           | miss     | Mem[0]               |       |       |       |
# | 8             | 0           | miss     | Mem[0] (Replacement) | Mem[8]     |       |       |
# | 0             | 0           | hit     | Mem[0] (Replacement) |  Mem[8]     |       |       |
# | 6             | 2           | miss     | Mem [0]               |Mem[6]     |  mem[6]     | |
# | 8             | 0           | hit     | Mem[8] (Replacement) |  Mem[6]     |   mem[6]   | |

# %% [markdown]
# ## Cache cont.
# * Cache Size = # sets * # blocks per set * block size
# * Replacement policy:
#   * Prefer empty entry, otherwise choos among entries in set
#   * replace the block accessed furthest in the future
#     * requires knowing the future
#   * if not recently used, less likely to be used in the future (locality)
#   * choose the one unused for the longest time
# * Write Policy:
#   * writes are cached, and written to main memory
#   * Write-back:
#     * writes are cached, but not written to main mem. until replaced
#     * add 1 bit (dirty bit) per clock to record if it has been written to
#
# ## Virtual Memory (managed by OS):
# |Virtual page #| Page Offset|
# |-|-|
# |V|P|
# * Used by CPU, main memory uses physical addresses
# * Software caches (not real): fast and cheap
# * use main memory as a 'cache' for hard disk
# * Programs share main memory
#   * protected from each other
#   * each get private virtual address space holding frequently used code and data
# * VM "block" is called a page
# * VM "miss" is called a page fault
# * hardware translates virtual addresses to physical addresses via the page map or page table (OS-managed)
#
# * Note: No index field since it is fully associative
# * offset = page offset ; never changes even after copied to memory
# * Virtual Address = Virtual page number + offset bits
#
# ## Page Table:
# |page #| Page Offset|
# |-|-|
# |M|P|
#
# * Page table is stored ?
#
# * Replacement:
#   * Prefer least-recently used to replace (LRU)
#     * Reference bit (use bit) set to 1 on access to page
#     * Periodically cleared to 0 by OS (not recently used)
#   * Dirty bit in PTE set when page is written
#
# ### Equations:
# 1. number of virtual pages (VM): $2^v$
# 2. number of physical pages (PT): $2^m$
# 3. bytes per physicla/virtual page: $2^p$
# 4. Bytes in physical memory (capacity, PT): $2^(m+p)$
# 5. bits in page table (pt): $(m+1+1+1) * 2^v$

# %% [markdown]
# <h1 style="color:#61dbfb ;"> Exam 3 on Weds. Dev 7</h1>

# %% [markdown]
# ### Speed up translation with a TLB:
# * Problem: 2 accesses for each memory reference
#   * Solution: Cache the page table entries within a TLB, Translation Look-aside Buffer
#
# ### Multi-level page tables:
# * Outer table consists of pointers to inner table (translation)
#   * If we do not need the memory, make pointers in outer table NULL.
#
# ### I/0 File Descriptor:
# * When you first open the file, the file descriptor is 3
# * Each process has 3 files open
#   * std input
#   * std output
#   * std error

# %% [markdown]
# # I/O and File System
# ```c
# #include <stdio.h>
# int main(void){
#     FILE *fp = fopen("output.txt","w");
#     if (!fp){
#         perror("output.txt");
#         return 1;
#     }
#     fputs("baby shark (do doo dooo)\n", fp);
#     if(fclose(fp)){
#         perror("output.txt");
#         return 1;
#     }
#     return 0;
# }
#
# FILE *fopen(const char *fname, const char *mode){
#     int fd = open(fnam, __mode2flags(mode), DEFFILEPERMS);
#     if (fd == -1){
#         return NULL;
#     }
#     return fdopen(fd, mode);
# }
#
# int fclose (FILE *fp){
#     int rv = close(fp->fd);
#     __ffree(fp);
#     return rv;
# }
#
# ```
#
# ```asm
# .globl close
# close:
#     mov $3, %eax
#     syscall
#     cmp $-4096, %rax
#     jae __syscall_error
#     ret
# ```
#
# ## Unix I/O
#
# A Linux *file* is a sequence of `m` bytes:
# * $B_0, B_1, ... , B_k, ... , B_{m-1}$
# * Each *file* has some kind of low-level name: inode (index node) number
#   * inode points to where the data of the file is stored
#
# All I/O devices are represented as file:
# * `/dev/tty2` (Terminal)
# * `/dev/sda2` (Disk Partition)
#
# Kernel data structures are exposed as files
# * `cat /proc/$$/status` (How long it has been running)
# * `ls -l /proc/$$/fd/`
#
# ### Types
# Two Abstractions: File and Directory
# * File:
#   * filename: human-readable
#   * low-level name: inode number
# * Directory
#   * low-level name: inode number
#   * contents are quite specific: pairs of (filename, inode number) or (subdirectory, inode number)
#
# Elegant mapping of files to devices allows kernel to export simple interface called Unix 1/0:
# * Opening and closing files
#   * `open()` and `close()`
# * Reading and writing a file
#   * `read()` and `write()`
# * Changing the *current file position* (seek)
#   * indicated next offset into file to read or write
#   * `lseek()`
#
# ### Directories
# Directory consists of array of links
# * Each link maps a filename to a file
# * Pairs of (filename, inode number)
#
# Each directory contains at least two entries
# * `.` (dot) is a link to itself
# * `..` (dot dot) is a link to the parent directory in the directory hierarchy
#
# Commands for manipulating directories
# * `mkdir`: create empty
# * `ls`: list contents of directory
# * `rmdir`: remove directory
#
# All files are organized as a hierarchy anchored by root directory named `/`
#
# Kernel maintains *current working directory* `cwd`
#
# Locations of files in the hierarchy denoted by *pathnames*
# * Aboslute pathname starts with `/` and denotes path from root
# * Relative pathname denotes path from current working directory
#
# ### Opening Files
# Opening a file informs the kernel that uou are getting ready to access that file
#
# ```c
# int fd; // file descriptor
#
# if ((fd = open("/etc/hosts", O_RDONLY)) < 0){
#     perror("open");
# ...
# ```
#
# file descriptor:
# * an integer
# * like a pointer to an object of type file; you can call methods to this
# * like a “pointer” to an object of type file; you can call “methods” to access the file: read(), write()
#
# When you first open a file, the file descriptor is 3
#
# Each running process already has three files open:
# * standard input (which the process can read to receive input)
# * standard output (which the process can write to in order to dump information to the screen)
# * standard error (which the process can write error messages to)
# * These are represented by file descriptors 0, 1, and 2, respectively
#
# ### Closing files
# Closing a file informs the kernel that you are finished accessing that file
# ```c
# if (close(fd) < 0) {
#    fprintf(stderr, "%s: write error: %s",
# exit(1);filename, strerror(errno));
# }
# ```
# Moral: Always check return codes, even for seemingly benign functions such as close()
#
# ### Reading Files
# Reading a file copies bytes from the current file position, and then updates file position
# ```c
# char buf[512];
# int fd;       /* file descriptor */
# int nbytes;   /* number of bytes read */
# /* Open file fd ...  */
# /* Then read up to 512 bytes from file fd */
# if ((nbytes = read(fd, buf, sizeof(buf))) < 0) {
# }
# perror("read");
# exit(1);
# ```
# Returns the number of bytes read from file `fd` into `buf`
# * Return types size_t is signed integer
# * nbytes < 0 indicates that an error occurred
# * Shortcounts`(nbytes<sizeof(buf))` are possible and are not errors!
#
# ### Writing Files
# Writing a file copies bytes to the current file position, and then updates current file position
# ```c
# char buf[512];
# int fd;       /* file descriptor */
# int nbytes;   /* number of bytes read */
# /* Open the file fd ... */
# /* Then write up to 512 bytes from buf to file fd */ if ((nbytes = write(fd, buf, sizeof(buf)) < 0) {
# }
# perror("write");
# exit(1);
# ```
# Returns number of bytes written from `buf` to file `fd`
# * nbytes < 0 indicates that an error occurred
# * As with reads, short counts are possible and are not errors!
#
# ### File Metadata
# Each file has an inode that stores *Metadata* (data about file data). This is maintained by kernel
#
# ### Practice
# 1.	What is the output of the following program?
# ```c
# int main(){
#     int fd1, fd2;
#     fd1 = open(“foo.txt”, O_RDONLY, 0);
#     close(fd1);
#     fd2 = open(‘baz.txt’, O_RDONLY, 0);
#     printf(“fd2 = %d\n”, fd2);
#     exit(0);
# }
# ```
# Output: `3`
#
# 2.	Suppose the disk file foobar.txt consists of the six ASCII characters foobar. What is the output of the following program?
# ```c
# int main(){
#     int fd1, fd2;
#     char c;
#     fd1 = open(“foobar.txt”, O_RDONLY, 0);
#     fd2 = open(“foobar.txt”, O_RDONLY, 0);
#     read(fd1, &c, 1);
#     read(fd2, &c, 1);
#     printf(“c = %c\n”, c);
#     exit(0);
# }
# ```
#
# Output: 'f'
#
# 3.	Suppose the disk file foobar.txt consists of the six ASCII characters foobar. What is the output of the following program?
# ```c
# int main(){
#     int fd;
#     char c;
#     fd = open(“foobar.txt”, O_RDONLY, 0);
#     if (fork()==0){
#     	read(fd, &c, 1);
#     	exit(0);
#     }
#     Wait(NULL);
#      read(fd, &c, 1);
#     printf(“c = %c\n”, c);
#     exit(0);
# }
# ```
#
# Output: c = 'o'

# %% [markdown]
# ```c
# int fd1;
# int s = rand()%10;
# char c1,c2;
# char *fname = argv[1];
# fd1 = Open(fname, O_RDONLY,0);
# Read(fd1,&c1,1);
# if(fork()){ // parent
#     sleep(s);
#     Read(fd1,&c2,1);
#     printf("Parent:c1 = %c, c2 = %c\n", c1,c2);
# }
# else{ //child
#     sleep(10-s);
#     Read(fd1,&c2,1);
#     printf("Child:c1 = %c, c2 = %c\n", c1,c2);
# }
# return 0;
# ```
# Result: (4 possibilities)
# * Parent:c1 = 'a', c2 = 'b'
# * Child:c1 = 'a', c2 = 'c'
# * OR
# * Parent:c1 = 'a', c2 = 'c'
# * Child: c1 = 'a',c2 = 'b'
#   * Can also print child first for either
#
# - OFT = Open File Table
# - (foo, 127456) = Hard link
# - Deleting a file does not necessarily free up space, we must unlink the file to the respective inode.
#
# ### Standard I/O functions:
# * Opening and closing files (fopen and fclose)
# * Reading and Writing bytes (fread and fwrite)
# * Reading and Writing text lines (fgets and fputs)
# * Formatted reading and writing (fscanf and fprintf)
#
# ### Inode and Data blocks:
# * Super block = stores disk information, system type, status, and other information
# * Bit map = determines index/size of following inodes, also has bits indicating if an indode has been used before.
#
# # Exam 3 Topics: (No Multiple Choice or True False!)
# 1. Cache: n-way set Associative
#    1. 1-way ... fully associative (comparison between them, cache index for direct-map)
#     * Convert mem. address to block number, then modulo to cache index for direct map or set number for fully associative
#     * Hit/Miss ratio
# 2. Virtual Memory and Physical Memory:
#    * Page size
#    * Page offset
#    * Number of pages
#    * Page table design
#      1. one level
#      2. Multi-level
# 3. Files, I/O
#    * System Calls, Dup2
#    * fork()
